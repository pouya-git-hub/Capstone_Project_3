# %%
# Let's start data wrangling on data_online_retail dataset.

# %%
# As the first step, I import Python libraries.

import numpy as np
import pandas as pd
import datetime as dt
import os

# %%
# The data source for this project is an Excel file.

retail_df = pd.read_csv('/content/data_online_retail.csv', encoding='latin1')

# %%
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
retail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49912 entries, 0 to 49911
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    49912 non-null  object
#  1   StockCode    49912 non-null  object
#  2   Description  49770 non-null  object
#  3   Quantity     49912 non-null  int64
#  4   InvoiceDate  49912 non-null  object
#  5   UnitPrice    49911 non-null  float64
#  6   CustomerID   32030 non-null  float64
#  7   Country      49911 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 3.0+ MB

# %%
retail_df.describe()
# Out:
#            Quantity     UnitPrice    CustomerID
# count  49912.000000  49911.000000  32030.000000
# mean       8.294218      6.423712  15426.016422
# std       55.576019    166.653120   1752.300279
# min    -9360.000000      0.000000  12347.000000
# 25%        1.000000      1.250000  14057.000000
# 50%        2.000000      2.510000  15464.000000
# 75%        8.000000      4.250000  17041.000000
# max     2880.000000  16888.020000  18283.000000

# %%
retail_df.describe().T
# Out:
#               count          mean          std      min       25%       50%  \
# Quantity    49912.0      8.294218    55.576019  -9360.0      1.00      2.00
# UnitPrice   49911.0      6.423712   166.653120      0.0      1.25      2.51
# CustomerID  32030.0  15426.016422  1752.300279  12347.0  14057.00  15464.00
#
#                  75%       max
# Quantity        8.00   2880.00
# UnitPrice       4.25  16888.02
# CustomerID  17041.00  18283.00

# %%
retail_df.shape
# Out:
# (49912, 8)

# %%
retail_df.isnull().sum()
# Out:
# InvoiceNo          0
# StockCode          0
# Description      142
# Quantity           0
# InvoiceDate        0
# UnitPrice          1
# CustomerID     17882
# Country            1
# dtype: int64

# %%
# Let's drop Null values from customer_id and Description, since both of those are small portions of dataframe.

retail_df = retail_df.dropna(subset=['CustomerID'])
retail_df = retail_df.dropna(subset=['Description'])

# %%
retail_df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
retail_df.shape
# Out:
# (32030, 8)

# %%
# Let's chaeck data types:

retail_df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
# These data types need to be changed:

# InvoiceDate >>> from string to datetime
# InvoiceNo >>> from string to float64
# Quantity >>> from float to integer

# However, InvoiceNo cannot be converted to float because it includes alphabet letters. So we keep it as string.

retail_df['InvoiceDate'] = pd.to_datetime(retail_df['InvoiceDate'])

retail_df['Quantity'] = retail_df['Quantity'].astype('int64')

# %%
retail_df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
# Everything else looks good to me.
# We do not have any Null values.
# All data types are correct.
# All columns have appropriate name.

# %%
# Let's print head and tail of retail_df and see if we can find something to explore.

retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
retail_df.tail()
# Out:
#       InvoiceNo StockCode                        Description  Quantity  \
# 49906    540538     47422   ASSORTED MONKEY SUCTION CUP HOOK         1
# 49907    540538     47422   ASSORTED MONKEY SUCTION CUP HOOK         5
# 49908    540538     21976     PACK OF 60 MUSHROOM CAKE CASES         9
# 49909    540538     84991        60 TEATIME FAIRY CAKE CASES         5
# 49910    540538     20969  RED FLORAL FELTCRAFT SHOULDER BAG         1
#
#               InvoiceDate  UnitPrice  CustomerID         Country
# 49906 2011-01-09 14:36:00       0.42     17841.0  United Kingdom
# 49907 2011-01-09 14:36:00       0.42     17841.0  United Kingdom
# 49908 2011-01-09 14:36:00       0.55     17841.0  United Kingdom
# 49909 2011-01-09 14:36:00       0.55     17841.0  United Kingdom
# 49910 2011-01-09 14:36:00       3.75     17841.0  United Kingdom

# %%
# Lets' find max and min price:

print(f"Cheapest item is {retail_df['UnitPrice'].min()}")

print(f"Most expensive item is {retail_df['UnitPrice'].max()}")
# Out:
# Cheapest item is 0.0
# Most expensive item is 1126.0

# %%
# The cheapest item is 0$ which means the data was not captured. I keep those rows since we still can extract useful information.

# %%
# Let's find mosgt ordered and least ordered items:

print(f"Most ordered item is {retail_df['Quantity'].max()}")
print(f"Least ordered item is {retail_df['Quantity'].min()}")
# Out:
# Most ordered item is 2880
# Least ordered item is -9360

# %%
# Weird! We have negative quantity. Let's explore the Quantity:

retail_df['Quantity'].unique()
# Out:
# array([    6,     8,     2,    32,     3,     4,    24,    12,    48,
#           18,    20,    36,    80,    64,    10,   120,    96,    23,
#            5,     1,    -1,    50,    40,   100,   192,   432,   144,
#          288,   -12,   -24,    16,     9,   128,    25,    30,    28,
#            7,    72,   200,   600,   480,    -6,    14,    -2,    -4,
#           -5,    -7,    -3,    11,    70,   252,    60,   216,   384,
#           27,   108,    52, -9360,    75,   270,    42,   240,    90,
#          320,    17,  1824,   204,    69,   -36,  -192,  -144,   160,
#         2880,  1400,    19,    39,   -48,   -50,    56,    13,  1440,
#           -8,    15,   720,   -20,   156,   324,    41,   -10,   -72,
#          -11,   402,   378,   150,   300,    22,    34,   408,   972,
#          208,  1008,    26,  1000,   -25,  1488,   250,  1394,   400,
#          110,   -14,    37,   -33,    78,    -9,    21,   272,    84,
#          -47,   -18,   -96,    47,   -15,   -30,  1728,    38,   -60,
#          -16,    53,  -240,    76,   576,   -32,    29,  2400,   500,
#          -80,   180,  -300,  -500,   -23,   -13,   960,   -21,  1296,
#         -150,   -17,   147,   168,   256,   -40,  -100,    54])

# %%
# Negative quantity is misleading. Let's change them to zero.

retail_df['Quantity'] = retail_df['Quantity'].where(retail_df['Quantity'] >= 0, 0)

retail_df['Quantity'].unique()
# Out:
# array([   6,    8,    2,   32,    3,    4,   24,   12,   48,   18,   20,
#          36,   80,   64,   10,  120,   96,   23,    5,    1,    0,   50,
#          40,  100,  192,  432,  144,  288,   16,    9,  128,   25,   30,
#          28,    7,   72,  200,  600,  480,   14,   11,   70,  252,   60,
#         216,  384,   27,  108,   52,   75,  270,   42,  240,   90,  320,
#          17, 1824,  204,   69,  160, 2880, 1400,   19,   39,   56,   13,
#        1440,   15,  720,  156,  324,   41,  402,  378,  150,  300,   22,
#          34,  408,  972,  208, 1008,   26, 1000, 1488,  250, 1394,  400,
#         110,   37,   78,   21,  272,   84,   47, 1728,   38,   53,   76,
#         576,   29, 2400,  500,  180,  960, 1296,  147,  168,  256,   54])

# %%
# As the last step, let's see which customer purchased more items:

retail_df['CustomerID'].value_counts()
# Out:
# CustomerID
# 12748.0    684
# 17841.0    374
# 14911.0    333
# 14606.0    333
# 17850.0    297
#           ...
# 13481.0      1
# 14608.0      1
# 12503.0      1
# 13748.0      1
# 13747.0      1
# Name: count, Length: 1038, dtype: int64

# %%
# I would like to use describe() method again to see if I can find outliers at this stage:

retail_df.describe().T
# Out:
#                count                           mean                  min  \
# Quantity     32030.0                      11.888261                  0.0
# InvoiceDate    32030  2010-12-14 14:16:39.205120256  2010-12-01 08:26:00
# UnitPrice    32030.0                       3.222959                  0.0
# CustomerID   32030.0                   15426.016422              12347.0
#
#                              25%                  50%                  75%  \
# Quantity                     2.0                  4.0                 12.0
# InvoiceDate  2010-12-06 10:20:00  2010-12-10 14:54:00  2010-12-17 12:56:00
# UnitPrice                   1.25                  2.1                 3.75
# CustomerID               14057.0              15464.0              17041.0
#
#                              max          std
# Quantity                  2880.0    43.533005
# InvoiceDate  2011-01-09 14:36:00          NaN
# UnitPrice                 1126.0     8.501477
# CustomerID               18283.0  1752.300279

# %%
# Max number of Quantity is 74215, which means a customer has that many order. Let's dive deeper on this:

retail_df['Quantity'].sort_values(ascending=False).head(10)
# Out:
# 4945     2880
# 32671    2400
# 4850     1824
# 25920    1728
# 19871    1488
# 6365     1440
# 4946     1400
# 19980    1394
# 40060    1296
# 16436    1008
# Name: Quantity, dtype: int64

# %%
# Yes! I just found an outlier. I am going to remove Quantity of 74215 since that looks a wrong captured data.
# This value definitely affect std of Quantity attribute.

retail_df = retail_df[retail_df['Quantity'] != 74215]

# %%
# Let's do the exact same process to see if we find any outliers in UnitPrice column:

retail_df['UnitPrice'].sort_values(ascending=False).head(10)
# Out:
# 45622    1126.00
# 36165     295.00
# 4989      295.00
# 32484     295.00
# 14498     281.00
# 19392     267.12
# 33105     175.00
# 25168     175.00
# 19428     165.00
# 246       165.00
# Name: UnitPrice, dtype: float64

# %%
# And also sort prices from low to high:

retail_df['UnitPrice'].sort_values().head(10)
# Out:
# 47070    0.00
# 47068    0.00
# 33576    0.00
# 9302     0.00
# 40089    0.00
# 4287     0.03
# 14788    0.07
# 45133    0.10
# 25189    0.10
# 31508    0.10
# Name: UnitPrice, dtype: float64

# %%
# We cannopt rely on UnitPrice average, because we have so many values close to zero which looks not correct.
# I do not remove these values, but I make sure to not involve average price value in my analysis.

# There are also two UnitPrice values which are much higher than others.
# Hard to say if those are bad data becasue an online store may have expensive items as well.
# Howeve, if those super expensive items are ordered only one time, we can remove them since they do not easily go under any segment.

# %%
retail_df['UnitPrice'][retail_df['UnitPrice'] > 500].count()
# Out:
# np.int64(1)

# %%
# Only two ordered items are that much expensive.
# I remove those two values because this online retail should not sell items with those prices.

retail_df = retail_df[retail_df['UnitPrice'] <= 500]

# %%
# We should see some change in mean value if I call describe() again:

retail_df.describe().T
# Out:
#                count                           mean                  min  \
# Quantity     32029.0                      11.888632                  0.0
# InvoiceDate    32029  2010-12-14 14:15:37.434200320  2010-12-01 08:26:00
# UnitPrice    32029.0                       3.187904                  0.0
# CustomerID   32029.0                   15426.107684              12347.0
#
#                              25%                  50%                  75%  \
# Quantity                     2.0                  4.0                 12.0
# InvoiceDate  2010-12-06 10:20:00  2010-12-10 14:54:00  2010-12-17 12:56:00
# UnitPrice                   1.25                  2.1                 3.75
# CustomerID               14057.0              15464.0              17041.0
#
#                              max          std
# Quantity                  2880.0    43.533634
# InvoiceDate  2011-01-09 14:36:00          NaN
# UnitPrice                  295.0     5.737242
# CustomerID               18283.0  1752.251512

# %%
# Let's count unique number of CustomerID:

retail_df['CustomerID'].nunique()
# Out:
# 1037

# %%
# And unique number of InvoiceNo:

retail_df['InvoiceNo'].nunique()
# Out:
# 1975

# %%
# I saw some of InvoiceNo has alphabetic letter C, which is a wrong format for this dataset.
# I need to remove those Invoices, so then I can canvert data type from string to integer:

retail_df = retail_df[~retail_df['InvoiceNo'].str.contains('C')]

# %%
# Now, let's check data type first, and then convert InvoiceNo from string to integer:

retail_df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
# Convert InvoiceNo from string to integer:

retail_df['InvoiceNo'].astype('int64')
# Out:
# 0        536365
# 1        536365
# 2        536365
# 3        536365
# 4        536365
#           ...
# 49906    540538
# 49907    540538
# 49908    540538
# 49909    540538
# 49910    540538
# Name: InvoiceNo, Length: 31150, dtype: int64

# %%
retail_df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
# We are done with data cleaning. The data looks clean now.
# Let's save the result to new Excel file and keep it for future work.

retail_df.to_csv('cleansed_data.csv', index=False)
